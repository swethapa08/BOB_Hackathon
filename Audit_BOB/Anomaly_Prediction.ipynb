# %%
import pandas as pd
data = pd.read_csv('financial_transactions.csv')
data.fillna(0, inplace=True)

# %%
from sklearn.ensemble import IsolationForest

# %%
model = IsolationForest(contamination=0.1)
model.fit(data)
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but IsolationForest was fitted with feature names
#   warnings.warn(
# IsolationForest(contamination=0.1)

# %%
data['anomaly'] = model.predict(data)
anomalies = data[data['anomaly'] == -1]

# %%
data
# Out:
#        transaction_id  customer_id   amount  anomaly
# 0                   1          926  6478.39       -1
# 1                   2          466  1255.95       -1
# 2                   3          110  7969.68       -1
# 3                   4          142  2927.41       -1
# 4                   5          944  4661.88       -1
# ...               ...          ...      ...      ...
# 99995           99996           40  8572.18       -1
# 99996           99997          951  1861.95       -1
# 99997           99998          533  8265.77        1
# 99998           99999           65  6874.50       -1
# 99999          100000          475  5258.85        1
#
# [100000 rows x 4 columns]
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data['transaction_id'].plot(kind='hist', bins=20, title='transaction_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data['customer_id'].plot(kind='hist', bins=20, title='customer_id')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data['amount'].plot(kind='hist', bins=20, title='amount')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data['anomaly'].plot(kind='hist', bins=20, title='anomaly')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">2-d distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data.plot(kind='scatter', x='transaction_id', y='customer_id', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data.plot(kind='scatter', x='customer_id', y='amount', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# data.plot(kind='scatter', x='amount', y='anomaly', s=32, alpha=.8)
# plt.gca().spines[['top', 'right',]].set_visible(False)
# <h4 class="colab-quickchart-section-title">Time series</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['transaction_id']
#   ys = series['customer_id']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = data.sort_values('transaction_id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('transaction_id')
# _ = plt.ylabel('customer_id')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['transaction_id']
#   ys = series['amount']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = data.sort_values('transaction_id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('transaction_id')
# _ = plt.ylabel('amount')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   xs = series['transaction_id']
#   ys = series['anomaly']
#
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = data.sort_values('transaction_id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('transaction_id')
# _ = plt.ylabel('anomaly')
# from matplotlib import pyplot as plt
# import seaborn as sns
# def _plot_series(series, series_name, series_index=0):
#   palette = list(sns.palettes.mpl_palette('Dark2'))
#   counted = (series['transaction_id']
#                 .value_counts()
#               .reset_index(name='counts')
#               .rename({'index': 'transaction_id'}, axis=1)
#               .sort_values('transaction_id', ascending=True))
#   xs = counted['transaction_id']
#   ys = counted['counts']
#   plt.plot(xs, ys, label=series_name, color=palette[series_index % len(palette)])
#
# fig, ax = plt.subplots(figsize=(10, 5.2), layout='constrained')
# df_sorted = data.sort_values('transaction_id', ascending=True)
# _plot_series(df_sorted, '')
# sns.despine(fig=fig, ax=ax)
# plt.xlabel('transaction_id')
# _ = plt.ylabel('count()')
# <h4 class="colab-quickchart-section-title">Values</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# data['transaction_id'].plot(kind='line', figsize=(8, 4), title='transaction_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# data['customer_id'].plot(kind='line', figsize=(8, 4), title='customer_id')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# data['amount'].plot(kind='line', figsize=(8, 4), title='amount')
# plt.gca().spines[['top', 'right']].set_visible(False)
# from matplotlib import pyplot as plt
# data['anomaly'].plot(kind='line', figsize=(8, 4), title='anomaly')
# plt.gca().spines[['top', 'right']].set_visible(False)
# Warning: total number of rows (100000) exceeds max_rows (20000). Limiting to first (20000) rows.
# Warning: total number of rows (100000) exceeds max_rows (20000). Limiting to first (20000) rows.

# %%
from matplotlib import pyplot as plt
data['amount'].plot(kind='line', figsize=(8, 4), title='amount')
plt.gca().spines[['top', 'right']].set_visible(False)

# %%
from matplotlib import pyplot as plt
data['customer_id'].plot(kind='line', figsize=(8, 4), title='customer_id')
plt.gca().spines[['top', 'right']].set_visible(False)
